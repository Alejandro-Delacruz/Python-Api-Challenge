# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

np.random.seed(0)
# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
cities
# Out:
# Number of cities in the list: 598
# ['bubaque',
#  'lushunkou',
#  'arcelia',
#  'wenchi',
#  'samarai',
#  'iranshahr',
#  'kawalu',
#  'tromso',
#  'pevek',
#  'chiredzi',
#  'bethel',
#  'lazaro cardenas',
#  'sao filipe',
#  'tumannyy',
#  'albany',
#  'ushuaia',
#  'busselton',
#  'vanavara',
#  'sept-iles',
#  'komsomolskiy',
#  'belushya guba',
#  'imeni poliny osipenko',
#  'tshikapa',
#  'aktash',
#  'katsuura',
#  'rikitea',
#  'longyearbyen',
#  'mataura',
#  'nikolskoye',
#  'tual',
#  'hilo',
#  'hermanus',
#  'arvi',
#  'jatni',
#  'khatanga',
#  'hamilton',
#  'jamestown',
#  'hithadhoo',
#  'ukiah',
#  'punta arenas',
#  'marrakesh',
#  'havelock',
#  'mount gambier',
#  'port elizabeth',
#  'treinta y tres',
#  'yulara',
#  'tuy hoa',
#  'asau',
#  'tiksi',
#  'kapaa',
#  'mar del plata',
#  'kimbe',
#  'tuatapere',
#  'east london',
#  'taolanaro',
#  'bredasdorp',
#  'concepcion',
#  'kodiak',
#  'paamiut',
#  'berlevag',
#  'narsaq',
#  'codrington',
#  'lebu',
#  'tsihombe',
#  'geraldton',
#  'kununurra',
#  'airai',
#  'port alfred',
#  'moyo',
#  'vaini',
#  'butaritari',
#  'tuktoyaktuk',
#  'carnarvon',
#  'caohe',
#  'redlands',
#  'mekhe',
#  'arman',
#  'hasaki',
#  'arraial do cabo',
#  'brewster',
#  'cherskiy',
#  'waipawa',
#  'san patricio',
#  'salalah',
#  'saskylakh',
#  'olafsvik',
#  'ribeira grande',
#  'laguna',
#  'andreapol',
#  'mount isa',
#  'srednekolymsk',
#  'makakilo city',
#  'yellowknife',
#  'fortuna',
#  'evanston',
#  'oriximina',
#  'barentsburg',
#  'riyadh',
#  'bluff',
#  'saint-philippe',
#  'shenjiamen',
#  'cockburn town',
#  'milingimbi',
#  'avarua',
#  'san andres',
#  'bababe',
#  'qandala',
#  'khash',
#  'srandakan',
#  'vila velha',
#  'namibe',
#  'husavik',
#  'magistralnyy',
#  'severo-kurilsk',
#  'barrow',
#  'dongsheng',
#  'norman wells',
#  'bilma',
#  'sorvag',
#  'champerico',
#  'bengkulu',
#  'new norfolk',
#  'yithion',
#  'georgetown',
#  'yozgat',
#  'bambous virieux',
#  'sarangani',
#  'oktyabrskiy',
#  'beloha',
#  'haimen',
#  'anito',
#  'qaanaaq',
#  'hoi an',
#  'yumen',
#  'luderitz',
#  'isangel',
#  'hobart',
#  'bend',
#  'plettenberg bay',
#  'swan hill',
#  'broome',
#  'puerto ayora',
#  'cravo norte',
#  'necochea',
#  'esperance',
#  'miles city',
#  'manzanillo',
#  'yerbogachen',
#  'jinji',
#  'the pas',
#  'piney green',
#  'mogadouro',
#  'rio gallegos',
#  'tiarei',
#  'sumbawa',
#  'solovetskiy',
#  'yuzawa',
#  'karratha',
#  'salinas',
#  'ampanihy',
#  'ilulissat',
#  'gulshat',
#  'bay roberts',
#  'castro',
#  'amderma',
#  'kahului',
#  'mahebourg',
#  'jomalig',
#  'harper',
#  'sorland',
#  'illoqqortoormiut',
#  'havre-saint-pierre',
#  'zhigansk',
#  'ostersund',
#  'upernavik',
#  'mendahara',
#  'lompoc',
#  'port hedland',
#  'mogadishu',
#  'lulea',
#  'andenes',
#  'chapais',
#  'ahipara',
#  'hihifo',
#  'comodoro rivadavia',
#  'kastoria',
#  'abay',
#  'anqing',
#  'onega',
#  'lata',
#  'muroto',
#  'methoni',
#  'rotterdam',
#  'nagato',
#  'alihe',
#  'caravelas',
#  'grand river south east',
#  'atuona',
#  'krasnoarmeysk',
#  'axim',
#  'richards bay',
#  'ixtapa',
#  'lima',
#  'bonthe',
#  'kavieng',
#  'algodones',
#  'poum',
#  'seguela',
#  'alta floresta',
#  'peniche',
#  'naftah',
#  'sakaiminato',
#  'marystown',
#  'la paz',
#  'cidreira',
#  'ilula',
#  'copala',
#  'vilyuysk',
#  'humaita',
#  'aklavik',
#  'tigil',
#  'terrace',
#  'panaba',
#  'grand gaube',
#  'montepuez',
#  'te anau',
#  'noyabrsk',
#  'souillac',
#  'talnakh',
#  'beisfjord',
#  'kempsey',
#  'naze',
#  'kruisfontein',
#  'moanda',
#  'half moon bay',
#  'chuy',
#  'oyama',
#  'praya',
#  'nur',
#  'toliary',
#  'palana',
#  'provideniya',
#  'mys shmidta',
#  'dikson',
#  'cape town',
#  'portland',
#  'lasa',
#  'kaitangata',
#  'meriden',
#  'thompson',
#  'yate',
#  'redmond',
#  'tilichiki',
#  'coihaique',
#  'kieta',
#  'atar',
#  'inuvik',
#  'backa palanka',
#  'saint-francois',
#  'bom sucesso',
#  'ostrovnoy',
#  'lavrentiya',
#  'cap malheureux',
#  'mumford',
#  'oron',
#  'merrill',
#  'kajaani',
#  'olinda',
#  'coquimbo',
#  'north bend',
#  'huntington',
#  'asfi',
#  'belaya gora',
#  'tire',
#  'navirai',
#  'burica',
#  'francisco sa',
#  'kaeo',
#  'dawei',
#  'san lawrenz',
#  'tasiilaq',
#  'ponta do sol',
#  'chilakalurupet',
#  'lar gerd',
#  'moose factory',
#  'sibolga',
#  'gizo',
#  'puerto baquerizo moreno',
#  'gat',
#  'verkhnyaya inta',
#  'gorontalo',
#  'klaksvik',
#  'itarema',
#  'alekseyevsk',
#  'santa rosa',
#  'pacific grove',
#  'atambua',
#  'korla',
#  'saint george',
#  'talcahuano',
#  'lydenburg',
#  'san cristobal',
#  'sao joao da barra',
#  'turayf',
#  'touros',
#  'engenheiro beltrao',
#  'samusu',
#  'sur',
#  'nanchang',
#  'grindavik',
#  'chokurdakh',
#  'channel-port aux basques',
#  'carnduff',
#  'cabo san lucas',
#  'liverpool',
#  'mirnyy',
#  'koutsouras',
#  'laredo',
#  'viligili',
#  'egvekinot',
#  'mabama',
#  'san ramon',
#  'krasnoselkup',
#  'sentyabrskiy',
#  'muscat',
#  'haapiti',
#  'longonjo',
#  'sakakah',
#  'aksu',
#  'giraldo',
#  'bowen',
#  'najran',
#  'licata',
#  'bilibino',
#  'lakatoro',
#  'eyl',
#  'saleaula',
#  'haines junction',
#  'petropavlovsk-kamchatskiy',
#  'soyo',
#  'sao jose da coroa grande',
#  'parrita',
#  'petropavlovka',
#  'levokumskoye',
#  'fayaoue',
#  'emerald',
#  'kamwenge',
#  'tocopilla',
#  'doctor pedro p. pena',
#  'burnie',
#  'ancud',
#  'mosquera',
#  'bodden town',
#  'thinadhoo',
#  'ruatoria',
#  'port blair',
#  'viedma',
#  'a',
#  'uige',
#  'mont-dore',
#  'attawapiskat',
#  'nizhniy tsasuchey',
#  'talaya',
#  'vestbygda',
#  'damaturu',
#  'rawson',
#  'mushie',
#  'guilin',
#  'sitka',
#  'denizli',
#  'dreux',
#  'tungkang',
#  'college',
#  'cervo',
#  'brae',
#  'chumikan',
#  'kidal',
#  'louisbourg',
#  'constitucion',
#  'beringovskiy',
#  'kindu',
#  'wakuya',
#  'fare',
#  'kovernino',
#  'katobu',
#  'coos bay',
#  'hualmay',
#  'vaitupu',
#  'yankton',
#  'collierville',
#  'nizhneyansk',
#  'utiroa',
#  'pisco',
#  'ilhabela',
#  'nara',
#  'mehamn',
#  'sisimiut',
#  'cayenne',
#  'broken hill',
#  'valparaiso',
#  'morros',
#  'kirakira',
#  'jiuquan',
#  'eureka',
#  'pinawa',
#  'kitimat',
#  'sao joaquim',
#  'torbay',
#  'kanigoro',
#  'sampit',
#  'padang',
#  'puerto colombia',
#  'taoudenni',
#  'coahuayana',
#  'ayan',
#  'vardo',
#  'dickinson',
#  'mercedes',
#  'cocoa beach',
#  'prainha',
#  'deputatskiy',
#  'yuzhno-yeniseyskiy',
#  'ballina',
#  'tucurui',
#  'uinskoye',
#  'linqing',
#  'shache',
#  'upington',
#  'hendek',
#  'palmer',
#  'general roca',
#  'nabire',
#  'anchorage',
#  'aswan',
#  'auki',
#  'port augusta',
#  'sovetskiy',
#  'klamath falls',
#  'makokou',
#  'biltine',
#  'polessk',
#  'mahon',
#  'vinh long',
#  'inongo',
#  'igarka',
#  'okhotsk',
#  'blyznyuky',
#  'carutapera',
#  'beruni',
#  'kudahuvadhoo',
#  'birjand',
#  'pandan',
#  'khalkhal',
#  'yanam',
#  'victoria',
#  'bull savanna',
#  'eganville',
#  'dingle',
#  'vrangel',
#  'pemba',
#  'raudeberg',
#  'biak',
#  'russell',
#  'wunstorf',
#  'colares',
#  'eskasem',
#  'port keats',
#  'hamamatsu',
#  'wattegama',
#  'belmonte',
#  'kyra',
#  'terrak',
#  'beihai',
#  'nam tha',
#  'rajapalaiyam',
#  'kodinsk',
#  'derzhavinsk',
#  'galle',
#  'omboue',
#  'bokspits',
#  'soe',
#  'vestmannaeyjar',
#  'yemtsa',
#  'leningradskiy',
#  'mecca',
#  'amalapuram',
#  'shasta lake',
#  'arica',
#  'miraflores',
#  'bowling green',
#  'san martin',
#  'la ronge',
#  'abu dhabi',
#  'brive-la-gaillarde',
#  'riachao das neves',
#  'novonukutskiy',
#  'saldanha',
#  'pingyi',
#  'rio grande',
#  'seydi',
#  'marsh harbour',
#  'los aquijes',
#  'alamosa',
#  'jalu',
#  'maniitsoq',
#  'labuhan',
#  'praia',
#  'margate',
#  'tevaitoa',
#  'dudinka',
#  'kalevala',
#  'novaya zaimka',
#  'stodolishche',
#  'ketchikan',
#  'san quintin',
#  'steinbach',
#  'solenzo',
#  'manzhouli',
#  'mali',
#  'la sierra',
#  'port-cartier',
#  'chaplynka',
#  'caxito',
#  'walvis bay',
#  'clyde river',
#  'galeana',
#  'nhulunbuy',
#  'macamic',
#  'camocim',
#  'belle fourche',
#  'toora-khem',
#  'nueve de julio',
#  'rey bouba',
#  'churapcha',
#  'gornopravdinsk',
#  'bolungarvik',
#  'camrose',
#  'guane',
#  'saint-felicien',
#  'tevriz',
#  'fairbanks',
#  'turzovka',
#  'zhuhai',
#  'yantal',
#  'pangnirtung',
#  'yeppoon',
#  'kloulklubed',
#  'chickasha',
#  'belousovka',
#  'marcona',
#  'quatre cocos',
#  'nacunday',
#  'koumac',
#  'baruun-urt',
#  'aljezur',
#  'ayagoz',
#  'neuquen',
#  'taraz',
#  'port lincoln',
#  'ust-ordynskiy',
#  'ures',
#  'sainte-luce',
#  'zabaykalsk',
#  'darhan',
#  'bijar',
#  'faanui',
#  'sai buri',
#  'byron bay',
#  'ailigandi',
#  'upleta',
#  'santa maria',
#  'hofn',
#  'brookhaven',
#  'banmankhi',
#  'tezu',
#  'stanesti',
#  'alofi',
#  'coihueco',
#  'tidore',
#  'jiroft',
#  'roquetas de mar',
#  'kachikau',
#  'salisbury',
#  'kizilskoye',
#  'vreed en hoop',
#  'gamba',
#  'borisoglebskiy',
#  'berdigestyakh',
#  'xiaoweizhai',
#  'palmas',
#  'san ignacio',
#  'camacha',
#  'tomball',
#  'keta',
#  'tsabong',
#  'moerai',
#  'tiznit',
#  'taltal']

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
parameters = {
    "q": cities[0],
    "appid": weather_api_key
}

response = requests.get(url="https://api.openweathermap.org/data/2.5/weather?", params=parameters)
results=response.json()
city_weather = results["weather"][0]["main"]
# Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
city_lat = results["coord"]["lat"]
city_lng = results["coord"]["lon"]
city_max_temp = results["main"]["temp_max"]-273.15
city_humidity = results["main"]["humidity"]
city_clouds = results["clouds"]["all"]
city_wind = results["wind"]["speed"]
city_country = results["sys"]["country"]
city_date = results["dt"]
# Out:
# {'coord': {'lon': -15.8333, 'lat': 11.2833},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 297.58,
#   'feels_like': 297.49,
#   'temp_min': 297.58,
#   'temp_max': 297.58,
#   'pressure': 1011,
#   'humidity': 54,
#   'sea_level': 1011,
#   'grnd_level': 1008},
#  'visibility': 10000,
#  'wind': {'speed': 6.87, 'deg': 337, 'gust': 7.87},
#  'clouds': {'all': 100},
#  'dt': 1675655109,
#  'sys': {'country': 'GW', 'sunrise': 1675668404, 'sunset': 1675710484},
#  'timezone': 0,
#  'id': 2374583,
#  'name': 'Bubaque',
#  'cod': 200}

# %%
# Set the API base URL
url="https://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    #city_url = # YOUR CODE HERE
    parameters = {
    "q": cities[i],
    "appid": weather_api_key
    }
    
    response = requests.get(url="https://api.openweathermap.org/data/2.5/weather?", params=parameters)
    results=response.json()
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        
        city_weather = results["weather"][0]["main"]
        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = results["coord"]["lat"]
        city_lng = results["coord"]["lon"]
        city_max_temp = results["main"]["temp_max"]
        city_humidity = results["main"]["humidity"]
        city_clouds = results["clouds"]["all"]
        city_wind = results["wind"]["speed"]
        city_country = results["sys"]["country"]
        city_date = results["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bubaque
# Processing Record 2 of Set 1 | lushunkou
# City not found. Skipping...
# Processing Record 3 of Set 1 | arcelia
# Processing Record 4 of Set 1 | wenchi
# Processing Record 5 of Set 1 | samarai
# Processing Record 6 of Set 1 | iranshahr
# Processing Record 7 of Set 1 | kawalu
# Processing Record 8 of Set 1 | tromso
# Processing Record 9 of Set 1 | pevek
# Processing Record 10 of Set 1 | chiredzi
# Processing Record 11 of Set 1 | bethel
# Processing Record 12 of Set 1 | lazaro cardenas
# Processing Record 13 of Set 1 | sao filipe
# Processing Record 14 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | busselton
# Processing Record 18 of Set 1 | vanavara
# Processing Record 19 of Set 1 | sept-iles
# Processing Record 20 of Set 1 | komsomolskiy
# Processing Record 21 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 1 | imeni poliny osipenko
# Processing Record 23 of Set 1 | tshikapa
# Processing Record 24 of Set 1 | aktash
# Processing Record 25 of Set 1 | katsuura
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | longyearbyen
# Processing Record 28 of Set 1 | mataura
# Processing Record 29 of Set 1 | nikolskoye
# Processing Record 30 of Set 1 | tual
# Processing Record 31 of Set 1 | hilo
# Processing Record 32 of Set 1 | hermanus
# Processing Record 33 of Set 1 | arvi
# Processing Record 34 of Set 1 | jatni
# City not found. Skipping...
# Processing Record 35 of Set 1 | khatanga
# Processing Record 36 of Set 1 | hamilton
# Processing Record 37 of Set 1 | jamestown
# Processing Record 38 of Set 1 | hithadhoo
# Processing Record 39 of Set 1 | ukiah
# Processing Record 40 of Set 1 | punta arenas
# Processing Record 41 of Set 1 | marrakesh
# Processing Record 42 of Set 1 | havelock
# Processing Record 43 of Set 1 | mount gambier
# Processing Record 44 of Set 1 | port elizabeth
# Processing Record 45 of Set 1 | treinta y tres
# Processing Record 46 of Set 1 | yulara
# Processing Record 47 of Set 1 | tuy hoa
# Processing Record 48 of Set 1 | asau
# Processing Record 49 of Set 1 | tiksi
# Processing Record 50 of Set 1 | kapaa
# Processing Record 0 of Set 2 | mar del plata
# Processing Record 1 of Set 2 | kimbe
# Processing Record 2 of Set 2 | tuatapere
# Processing Record 3 of Set 2 | east london
# Processing Record 4 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 2 | bredasdorp
# Processing Record 6 of Set 2 | concepcion
# Processing Record 7 of Set 2 | kodiak
# Processing Record 8 of Set 2 | paamiut
# Processing Record 9 of Set 2 | berlevag
# Processing Record 10 of Set 2 | narsaq
# Processing Record 11 of Set 2 | codrington
# Processing Record 12 of Set 2 | lebu
# Processing Record 13 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 14 of Set 2 | geraldton
# Processing Record 15 of Set 2 | kununurra
# Processing Record 16 of Set 2 | airai
# Processing Record 17 of Set 2 | port alfred
# Processing Record 18 of Set 2 | moyo
# Processing Record 19 of Set 2 | vaini
# Processing Record 20 of Set 2 | butaritari
# Processing Record 21 of Set 2 | tuktoyaktuk
# Processing Record 22 of Set 2 | carnarvon
# Processing Record 23 of Set 2 | caohe
# Processing Record 24 of Set 2 | redlands
# Processing Record 25 of Set 2 | mekhe
# Processing Record 26 of Set 2 | arman
# Processing Record 27 of Set 2 | hasaki
# Processing Record 28 of Set 2 | arraial do cabo
# Processing Record 29 of Set 2 | brewster
# Processing Record 30 of Set 2 | cherskiy
# Processing Record 31 of Set 2 | waipawa
# Processing Record 32 of Set 2 | san patricio
# Processing Record 33 of Set 2 | salalah
# Processing Record 34 of Set 2 | saskylakh
# Processing Record 35 of Set 2 | olafsvik
# Processing Record 36 of Set 2 | ribeira grande
# Processing Record 37 of Set 2 | laguna
# Processing Record 38 of Set 2 | andreapol
# Processing Record 39 of Set 2 | mount isa
# Processing Record 40 of Set 2 | srednekolymsk
# Processing Record 41 of Set 2 | makakilo city
# Processing Record 42 of Set 2 | yellowknife
# Processing Record 43 of Set 2 | fortuna
# Processing Record 44 of Set 2 | evanston
# Processing Record 45 of Set 2 | oriximina
# Processing Record 46 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 2 | riyadh
# Processing Record 48 of Set 2 | bluff
# Processing Record 49 of Set 2 | saint-philippe
# Processing Record 0 of Set 3 | shenjiamen
# Processing Record 1 of Set 3 | cockburn town
# Processing Record 2 of Set 3 | milingimbi
# City not found. Skipping...
# Processing Record 3 of Set 3 | avarua
# Processing Record 4 of Set 3 | san andres
# Processing Record 5 of Set 3 | bababe
# City not found. Skipping...
# Processing Record 6 of Set 3 | qandala
# Processing Record 7 of Set 3 | khash
# Processing Record 8 of Set 3 | srandakan
# Processing Record 9 of Set 3 | vila velha
# Processing Record 10 of Set 3 | namibe
# Processing Record 11 of Set 3 | husavik
# Processing Record 12 of Set 3 | magistralnyy
# Processing Record 13 of Set 3 | severo-kurilsk
# Processing Record 14 of Set 3 | barrow
# Processing Record 15 of Set 3 | dongsheng
# Processing Record 16 of Set 3 | norman wells
# Processing Record 17 of Set 3 | bilma
# Processing Record 18 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 19 of Set 3 | champerico
# Processing Record 20 of Set 3 | bengkulu
# Processing Record 21 of Set 3 | new norfolk
# Processing Record 22 of Set 3 | yithion
# City not found. Skipping...
# Processing Record 23 of Set 3 | georgetown
# Processing Record 24 of Set 3 | yozgat
# Processing Record 25 of Set 3 | bambous virieux
# Processing Record 26 of Set 3 | sarangani
# Processing Record 27 of Set 3 | oktyabrskiy
# Processing Record 28 of Set 3 | beloha
# Processing Record 29 of Set 3 | haimen
# Processing Record 30 of Set 3 | anito
# Processing Record 31 of Set 3 | qaanaaq
# Processing Record 32 of Set 3 | hoi an
# Processing Record 33 of Set 3 | yumen
# Processing Record 34 of Set 3 | luderitz
# Processing Record 35 of Set 3 | isangel
# Processing Record 36 of Set 3 | hobart
# Processing Record 37 of Set 3 | bend
# Processing Record 38 of Set 3 | plettenberg bay
# Processing Record 39 of Set 3 | swan hill
# Processing Record 40 of Set 3 | broome
# Processing Record 41 of Set 3 | puerto ayora
# Processing Record 42 of Set 3 | cravo norte
# Processing Record 43 of Set 3 | necochea
# Processing Record 44 of Set 3 | esperance
# Processing Record 45 of Set 3 | miles city
# Processing Record 46 of Set 3 | manzanillo
# Processing Record 47 of Set 3 | yerbogachen
# Processing Record 48 of Set 3 | jinji
# Processing Record 49 of Set 3 | the pas
# Processing Record 0 of Set 4 | piney green
# Processing Record 1 of Set 4 | mogadouro
# Processing Record 2 of Set 4 | rio gallegos
# Processing Record 3 of Set 4 | tiarei
# Processing Record 4 of Set 4 | sumbawa
# City not found. Skipping...
# Processing Record 5 of Set 4 | solovetskiy
# City not found. Skipping...
# Processing Record 6 of Set 4 | yuzawa
# Processing Record 7 of Set 4 | karratha
# Processing Record 8 of Set 4 | salinas
# Processing Record 9 of Set 4 | ampanihy
# Processing Record 10 of Set 4 | ilulissat
# Processing Record 11 of Set 4 | gulshat
# City not found. Skipping...
# Processing Record 12 of Set 4 | bay roberts
# Processing Record 13 of Set 4 | castro
# Processing Record 14 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 4 | kahului
# Processing Record 16 of Set 4 | mahebourg
# Processing Record 17 of Set 4 | jomalig
# City not found. Skipping...
# Processing Record 18 of Set 4 | harper
# Processing Record 19 of Set 4 | sorland
# Processing Record 20 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 4 | havre-saint-pierre
# Processing Record 22 of Set 4 | zhigansk
# Processing Record 23 of Set 4 | ostersund
# Processing Record 24 of Set 4 | upernavik
# Processing Record 25 of Set 4 | mendahara
# City not found. Skipping...
# Processing Record 26 of Set 4 | lompoc
# Processing Record 27 of Set 4 | port hedland
# Processing Record 28 of Set 4 | mogadishu
# Processing Record 29 of Set 4 | lulea
# Processing Record 30 of Set 4 | andenes
# Processing Record 31 of Set 4 | chapais
# Processing Record 32 of Set 4 | ahipara
# Processing Record 33 of Set 4 | hihifo
# City not found. Skipping...
# Processing Record 34 of Set 4 | comodoro rivadavia
# Processing Record 35 of Set 4 | kastoria
# Processing Record 36 of Set 4 | abay
# Processing Record 37 of Set 4 | anqing
# Processing Record 38 of Set 4 | onega
# Processing Record 39 of Set 4 | lata
# Processing Record 40 of Set 4 | muroto
# Processing Record 41 of Set 4 | methoni
# Processing Record 42 of Set 4 | rotterdam
# Processing Record 43 of Set 4 | nagato
# Processing Record 44 of Set 4 | alihe
# Processing Record 45 of Set 4 | caravelas
# Processing Record 46 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 4 | atuona
# Processing Record 48 of Set 4 | krasnoarmeysk
# Processing Record 49 of Set 4 | axim
# Processing Record 0 of Set 5 | richards bay
# Processing Record 1 of Set 5 | ixtapa
# Processing Record 2 of Set 5 | lima
# Processing Record 3 of Set 5 | bonthe
# Processing Record 4 of Set 5 | kavieng
# Processing Record 5 of Set 5 | algodones
# Processing Record 6 of Set 5 | poum
# Processing Record 7 of Set 5 | seguela
# Processing Record 8 of Set 5 | alta floresta
# Processing Record 9 of Set 5 | peniche
# Processing Record 10 of Set 5 | naftah
# City not found. Skipping...
# Processing Record 11 of Set 5 | sakaiminato
# Processing Record 12 of Set 5 | marystown
# Processing Record 13 of Set 5 | la paz
# Processing Record 14 of Set 5 | cidreira
# Processing Record 15 of Set 5 | ilula
# Processing Record 16 of Set 5 | copala
# Processing Record 17 of Set 5 | vilyuysk
# Processing Record 18 of Set 5 | humaita
# Processing Record 19 of Set 5 | aklavik
# Processing Record 20 of Set 5 | tigil
# Processing Record 21 of Set 5 | terrace
# Processing Record 22 of Set 5 | panaba
# Processing Record 23 of Set 5 | grand gaube
# Processing Record 24 of Set 5 | montepuez
# Processing Record 25 of Set 5 | te anau
# Processing Record 26 of Set 5 | noyabrsk
# Processing Record 27 of Set 5 | souillac
# Processing Record 28 of Set 5 | talnakh
# Processing Record 29 of Set 5 | beisfjord
# Processing Record 30 of Set 5 | kempsey
# Processing Record 31 of Set 5 | naze
# Processing Record 32 of Set 5 | kruisfontein
# Processing Record 33 of Set 5 | moanda
# Processing Record 34 of Set 5 | half moon bay
# Processing Record 35 of Set 5 | chuy
# Processing Record 36 of Set 5 | oyama
# Processing Record 37 of Set 5 | praya
# Processing Record 38 of Set 5 | nur
# Processing Record 39 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 40 of Set 5 | palana
# Processing Record 41 of Set 5 | provideniya
# Processing Record 42 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 5 | dikson
# Processing Record 44 of Set 5 | cape town
# Processing Record 45 of Set 5 | portland
# Processing Record 46 of Set 5 | lasa
# Processing Record 47 of Set 5 | kaitangata
# Processing Record 48 of Set 5 | meriden
# Processing Record 49 of Set 5 | thompson
# Processing Record 0 of Set 6 | yate
# Processing Record 1 of Set 6 | redmond
# Processing Record 2 of Set 6 | tilichiki
# Processing Record 3 of Set 6 | coihaique
# Processing Record 4 of Set 6 | kieta
# Processing Record 5 of Set 6 | atar
# Processing Record 6 of Set 6 | inuvik
# Processing Record 7 of Set 6 | backa palanka
# Processing Record 8 of Set 6 | saint-francois
# Processing Record 9 of Set 6 | bom sucesso
# Processing Record 10 of Set 6 | ostrovnoy
# Processing Record 11 of Set 6 | lavrentiya
# Processing Record 12 of Set 6 | cap malheureux
# Processing Record 13 of Set 6 | mumford
# Processing Record 14 of Set 6 | oron
# Processing Record 15 of Set 6 | merrill
# Processing Record 16 of Set 6 | kajaani
# Processing Record 17 of Set 6 | olinda
# Processing Record 18 of Set 6 | coquimbo
# Processing Record 19 of Set 6 | north bend
# Processing Record 20 of Set 6 | huntington
# Processing Record 21 of Set 6 | asfi
# Processing Record 22 of Set 6 | belaya gora
# Processing Record 23 of Set 6 | tire
# Processing Record 24 of Set 6 | navirai
# Processing Record 25 of Set 6 | burica
# City not found. Skipping...
# Processing Record 26 of Set 6 | francisco sa
# Processing Record 27 of Set 6 | kaeo
# Processing Record 28 of Set 6 | dawei
# Processing Record 29 of Set 6 | san lawrenz
# Processing Record 30 of Set 6 | tasiilaq
# Processing Record 31 of Set 6 | ponta do sol
# Processing Record 32 of Set 6 | chilakalurupet
# Processing Record 33 of Set 6 | lar gerd
# City not found. Skipping...
# Processing Record 34 of Set 6 | moose factory
# Processing Record 35 of Set 6 | sibolga
# Processing Record 36 of Set 6 | gizo
# Processing Record 37 of Set 6 | puerto baquerizo moreno
# Processing Record 38 of Set 6 | gat
# Processing Record 39 of Set 6 | verkhnyaya inta
# Processing Record 40 of Set 6 | gorontalo
# Processing Record 41 of Set 6 | klaksvik
# Processing Record 42 of Set 6 | itarema
# Processing Record 43 of Set 6 | alekseyevsk
# Processing Record 44 of Set 6 | santa rosa
# Processing Record 45 of Set 6 | pacific grove
# Processing Record 46 of Set 6 | atambua
# Processing Record 47 of Set 6 | korla
# Processing Record 48 of Set 6 | saint george
# Processing Record 49 of Set 6 | talcahuano
# Processing Record 0 of Set 7 | lydenburg
# Processing Record 1 of Set 7 | san cristobal
# Processing Record 2 of Set 7 | sao joao da barra
# Processing Record 3 of Set 7 | turayf
# Processing Record 4 of Set 7 | touros
# Processing Record 5 of Set 7 | engenheiro beltrao
# Processing Record 6 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 7 of Set 7 | sur
# Processing Record 8 of Set 7 | nanchang
# Processing Record 9 of Set 7 | grindavik
# Processing Record 10 of Set 7 | chokurdakh
# Processing Record 11 of Set 7 | channel-port aux basques
# Processing Record 12 of Set 7 | carnduff
# Processing Record 13 of Set 7 | cabo san lucas
# Processing Record 14 of Set 7 | liverpool
# Processing Record 15 of Set 7 | mirnyy
# Processing Record 16 of Set 7 | koutsouras
# Processing Record 17 of Set 7 | laredo
# Processing Record 18 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 19 of Set 7 | egvekinot
# Processing Record 20 of Set 7 | mabama
# Processing Record 21 of Set 7 | san ramon
# Processing Record 22 of Set 7 | krasnoselkup
# Processing Record 23 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 7 | muscat
# Processing Record 25 of Set 7 | haapiti
# Processing Record 26 of Set 7 | longonjo
# Processing Record 27 of Set 7 | sakakah
# Processing Record 28 of Set 7 | aksu
# Processing Record 29 of Set 7 | giraldo
# Processing Record 30 of Set 7 | bowen
# Processing Record 31 of Set 7 | najran
# Processing Record 32 of Set 7 | licata
# Processing Record 33 of Set 7 | bilibino
# Processing Record 34 of Set 7 | lakatoro
# Processing Record 35 of Set 7 | eyl
# Processing Record 36 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 37 of Set 7 | haines junction
# Processing Record 38 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 39 of Set 7 | soyo
# Processing Record 40 of Set 7 | sao jose da coroa grande
# Processing Record 41 of Set 7 | parrita
# Processing Record 42 of Set 7 | petropavlovka
# Processing Record 43 of Set 7 | levokumskoye
# Processing Record 44 of Set 7 | fayaoue
# Processing Record 45 of Set 7 | emerald
# Processing Record 46 of Set 7 | kamwenge
# Processing Record 47 of Set 7 | tocopilla
# Processing Record 48 of Set 7 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 49 of Set 7 | burnie
# Processing Record 0 of Set 8 | ancud
# Processing Record 1 of Set 8 | mosquera
# Processing Record 2 of Set 8 | bodden town
# Processing Record 3 of Set 8 | thinadhoo
# Processing Record 4 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 5 of Set 8 | port blair
# Processing Record 6 of Set 8 | viedma
# Processing Record 7 of Set 8 | a
# City not found. Skipping...
# Processing Record 8 of Set 8 | uige
# Processing Record 9 of Set 8 | mont-dore
# Processing Record 10 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 8 | nizhniy tsasuchey
# Processing Record 12 of Set 8 | talaya
# Processing Record 13 of Set 8 | vestbygda
# City not found. Skipping...
# Processing Record 14 of Set 8 | damaturu
# Processing Record 15 of Set 8 | rawson
# Processing Record 16 of Set 8 | mushie
# Processing Record 17 of Set 8 | guilin
# Processing Record 18 of Set 8 | sitka
# Processing Record 19 of Set 8 | denizli
# Processing Record 20 of Set 8 | dreux
# Processing Record 21 of Set 8 | tungkang
# City not found. Skipping...
# Processing Record 22 of Set 8 | college
# Processing Record 23 of Set 8 | cervo
# Processing Record 24 of Set 8 | brae
# Processing Record 25 of Set 8 | chumikan
# Processing Record 26 of Set 8 | kidal
# Processing Record 27 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 28 of Set 8 | constitucion
# Processing Record 29 of Set 8 | beringovskiy
# Processing Record 30 of Set 8 | kindu
# Processing Record 31 of Set 8 | wakuya
# Processing Record 32 of Set 8 | fare
# Processing Record 33 of Set 8 | kovernino
# Processing Record 34 of Set 8 | katobu
# Processing Record 35 of Set 8 | coos bay
# Processing Record 36 of Set 8 | hualmay
# Processing Record 37 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 8 | yankton
# Processing Record 39 of Set 8 | collierville
# Processing Record 40 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 42 of Set 8 | pisco
# Processing Record 43 of Set 8 | ilhabela
# Processing Record 44 of Set 8 | nara
# Processing Record 45 of Set 8 | mehamn
# Processing Record 46 of Set 8 | sisimiut
# Processing Record 47 of Set 8 | cayenne
# Processing Record 48 of Set 8 | broken hill
# Processing Record 49 of Set 8 | valparaiso
# Processing Record 0 of Set 9 | morros
# Processing Record 1 of Set 9 | kirakira
# Processing Record 2 of Set 9 | jiuquan
# Processing Record 3 of Set 9 | eureka
# Processing Record 4 of Set 9 | pinawa
# Processing Record 5 of Set 9 | kitimat
# Processing Record 6 of Set 9 | sao joaquim
# Processing Record 7 of Set 9 | torbay
# Processing Record 8 of Set 9 | kanigoro
# Processing Record 9 of Set 9 | sampit
# Processing Record 10 of Set 9 | padang
# Processing Record 11 of Set 9 | puerto colombia
# Processing Record 12 of Set 9 | taoudenni
# Processing Record 13 of Set 9 | coahuayana
# Processing Record 14 of Set 9 | ayan
# Processing Record 15 of Set 9 | vardo
# Processing Record 16 of Set 9 | dickinson
# Processing Record 17 of Set 9 | mercedes
# Processing Record 18 of Set 9 | cocoa beach
# Processing Record 19 of Set 9 | prainha
# Processing Record 20 of Set 9 | deputatskiy
# Processing Record 21 of Set 9 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 22 of Set 9 | ballina
# Processing Record 23 of Set 9 | tucurui
# Processing Record 24 of Set 9 | uinskoye
# Processing Record 25 of Set 9 | linqing
# Processing Record 26 of Set 9 | shache
# Processing Record 27 of Set 9 | upington
# Processing Record 28 of Set 9 | hendek
# Processing Record 29 of Set 9 | palmer
# Processing Record 30 of Set 9 | general roca
# Processing Record 31 of Set 9 | nabire
# Processing Record 32 of Set 9 | anchorage
# Processing Record 33 of Set 9 | aswan
# Processing Record 34 of Set 9 | auki
# Processing Record 35 of Set 9 | port augusta
# Processing Record 36 of Set 9 | sovetskiy
# Processing Record 37 of Set 9 | klamath falls
# Processing Record 38 of Set 9 | makokou
# Processing Record 39 of Set 9 | biltine
# Processing Record 40 of Set 9 | polessk
# Processing Record 41 of Set 9 | mahon
# Processing Record 42 of Set 9 | vinh long
# Processing Record 43 of Set 9 | inongo
# Processing Record 44 of Set 9 | igarka
# Processing Record 45 of Set 9 | okhotsk
# Processing Record 46 of Set 9 | blyznyuky
# Processing Record 47 of Set 9 | carutapera
# Processing Record 48 of Set 9 | beruni
# City not found. Skipping...
# Processing Record 49 of Set 9 | kudahuvadhoo
# Processing Record 0 of Set 10 | birjand
# Processing Record 1 of Set 10 | pandan
# Processing Record 2 of Set 10 | khalkhal
# Processing Record 3 of Set 10 | yanam
# Processing Record 4 of Set 10 | victoria
# Processing Record 5 of Set 10 | bull savanna
# Processing Record 6 of Set 10 | eganville
# Processing Record 7 of Set 10 | dingle
# Processing Record 8 of Set 10 | vrangel
# Processing Record 9 of Set 10 | pemba
# Processing Record 10 of Set 10 | raudeberg
# Processing Record 11 of Set 10 | biak
# Processing Record 12 of Set 10 | russell
# Processing Record 13 of Set 10 | wunstorf
# Processing Record 14 of Set 10 | colares
# Processing Record 15 of Set 10 | eskasem
# City not found. Skipping...
# Processing Record 16 of Set 10 | port keats
# Processing Record 17 of Set 10 | hamamatsu
# Processing Record 18 of Set 10 | wattegama
# Processing Record 19 of Set 10 | belmonte
# Processing Record 20 of Set 10 | kyra
# Processing Record 21 of Set 10 | terrak
# Processing Record 22 of Set 10 | beihai
# Processing Record 23 of Set 10 | nam tha
# City not found. Skipping...
# Processing Record 24 of Set 10 | rajapalaiyam
# Processing Record 25 of Set 10 | kodinsk
# Processing Record 26 of Set 10 | derzhavinsk
# Processing Record 27 of Set 10 | galle
# Processing Record 28 of Set 10 | omboue
# Processing Record 29 of Set 10 | bokspits
# City not found. Skipping...
# Processing Record 30 of Set 10 | soe
# Processing Record 31 of Set 10 | vestmannaeyjar
# Processing Record 32 of Set 10 | yemtsa
# Processing Record 33 of Set 10 | leningradskiy
# Processing Record 34 of Set 10 | mecca
# Processing Record 35 of Set 10 | amalapuram
# Processing Record 36 of Set 10 | shasta lake
# Processing Record 37 of Set 10 | arica
# Processing Record 38 of Set 10 | miraflores
# Processing Record 39 of Set 10 | bowling green
# Processing Record 40 of Set 10 | san martin
# Processing Record 41 of Set 10 | la ronge
# Processing Record 42 of Set 10 | abu dhabi
# Processing Record 43 of Set 10 | brive-la-gaillarde
# Processing Record 44 of Set 10 | riachao das neves
# Processing Record 45 of Set 10 | novonukutskiy
# Processing Record 46 of Set 10 | saldanha
# Processing Record 47 of Set 10 | pingyi
# Processing Record 48 of Set 10 | rio grande
# Processing Record 49 of Set 10 | seydi
# Processing Record 0 of Set 11 | marsh harbour
# Processing Record 1 of Set 11 | los aquijes
# Processing Record 2 of Set 11 | alamosa
# Processing Record 3 of Set 11 | jalu
# Processing Record 4 of Set 11 | maniitsoq
# Processing Record 5 of Set 11 | labuhan
# Processing Record 6 of Set 11 | praia
# Processing Record 7 of Set 11 | margate
# Processing Record 8 of Set 11 | tevaitoa
# Processing Record 9 of Set 11 | dudinka
# Processing Record 10 of Set 11 | kalevala
# Processing Record 11 of Set 11 | novaya zaimka
# Processing Record 12 of Set 11 | stodolishche
# Processing Record 13 of Set 11 | ketchikan
# Processing Record 14 of Set 11 | san quintin
# Processing Record 15 of Set 11 | steinbach
# Processing Record 16 of Set 11 | solenzo
# Processing Record 17 of Set 11 | manzhouli
# Processing Record 18 of Set 11 | mali
# Processing Record 19 of Set 11 | la sierra
# Processing Record 20 of Set 11 | port-cartier
# Processing Record 21 of Set 11 | chaplynka
# Processing Record 22 of Set 11 | caxito
# Processing Record 23 of Set 11 | walvis bay
# Processing Record 24 of Set 11 | clyde river
# Processing Record 25 of Set 11 | galeana
# Processing Record 26 of Set 11 | nhulunbuy
# Processing Record 27 of Set 11 | macamic
# Processing Record 28 of Set 11 | camocim
# Processing Record 29 of Set 11 | belle fourche
# Processing Record 30 of Set 11 | toora-khem
# Processing Record 31 of Set 11 | nueve de julio
# Processing Record 32 of Set 11 | rey bouba
# Processing Record 33 of Set 11 | churapcha
# Processing Record 34 of Set 11 | gornopravdinsk
# Processing Record 35 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 36 of Set 11 | camrose
# Processing Record 37 of Set 11 | guane
# Processing Record 38 of Set 11 | saint-felicien
# Processing Record 39 of Set 11 | tevriz
# Processing Record 40 of Set 11 | fairbanks
# Processing Record 41 of Set 11 | turzovka
# Processing Record 42 of Set 11 | zhuhai
# Processing Record 43 of Set 11 | yantal
# Processing Record 44 of Set 11 | pangnirtung
# Processing Record 45 of Set 11 | yeppoon
# Processing Record 46 of Set 11 | kloulklubed
# Processing Record 47 of Set 11 | chickasha
# Processing Record 48 of Set 11 | belousovka
# Processing Record 49 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 0 of Set 12 | quatre cocos
# Processing Record 1 of Set 12 | nacunday
# City not found. Skipping...
# Processing Record 2 of Set 12 | koumac
# Processing Record 3 of Set 12 | baruun-urt
# Processing Record 4 of Set 12 | aljezur
# Processing Record 5 of Set 12 | ayagoz
# Processing Record 6 of Set 12 | neuquen
# Processing Record 7 of Set 12 | taraz
# Processing Record 8 of Set 12 | port lincoln
# Processing Record 9 of Set 12 | ust-ordynskiy
# Processing Record 10 of Set 12 | ures
# Processing Record 11 of Set 12 | sainte-luce
# Processing Record 12 of Set 12 | zabaykalsk
# Processing Record 13 of Set 12 | darhan
# Processing Record 14 of Set 12 | bijar
# Processing Record 15 of Set 12 | faanui
# Processing Record 16 of Set 12 | sai buri
# Processing Record 17 of Set 12 | byron bay
# Processing Record 18 of Set 12 | ailigandi
# Processing Record 19 of Set 12 | upleta
# Processing Record 20 of Set 12 | santa maria
# Processing Record 21 of Set 12 | hofn
# Processing Record 22 of Set 12 | brookhaven
# Processing Record 23 of Set 12 | banmankhi
# Processing Record 24 of Set 12 | tezu
# Processing Record 25 of Set 12 | stanesti
# Processing Record 26 of Set 12 | alofi
# Processing Record 27 of Set 12 | coihueco
# Processing Record 28 of Set 12 | tidore
# City not found. Skipping...
# Processing Record 29 of Set 12 | jiroft
# City not found. Skipping...
# Processing Record 30 of Set 12 | roquetas de mar
# Processing Record 31 of Set 12 | kachikau
# City not found. Skipping...
# Processing Record 32 of Set 12 | salisbury
# Processing Record 33 of Set 12 | kizilskoye
# Processing Record 34 of Set 12 | vreed en hoop
# City not found. Skipping...
# Processing Record 35 of Set 12 | gamba
# Processing Record 36 of Set 12 | borisoglebskiy
# Processing Record 37 of Set 12 | berdigestyakh
# Processing Record 38 of Set 12 | xiaoweizhai
# Processing Record 39 of Set 12 | palmas
# Processing Record 40 of Set 12 | san ignacio
# Processing Record 41 of Set 12 | camacha
# Processing Record 42 of Set 12 | tomball
# Processing Record 43 of Set 12 | keta
# Processing Record 44 of Set 12 | tsabong
# Processing Record 45 of Set 12 | moerai
# Processing Record 46 of Set 12 | tiznit
# Processing Record 47 of Set 12 | taltal
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# convert the kelvin to celcius
city_data_df["Max Temp"]=city_data_df["Max Temp"]-273.15

# Show Record Count
city_data_df.count()
# Out:
# City          547
# Lat           547
# Lng           547
# Max Temp      547
# Humidity      547
# Cloudiness    547
# Wind Speed    547
# Country       547
# Date          547
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    bubaque  11.2833  -15.8333     24.43        54         100        6.87
# 1    arcelia  18.2833 -100.2667     24.14        37           0        1.46
# 2     wenchi   7.7392   -2.1046     23.51        77          84        1.81
# 3    samarai -10.6167  150.6667     27.40        83          99        5.80
# 4  iranshahr  27.2025   60.6848     12.19        71           0        2.06
#
#   Country        Date
# 0      GW  1675655109
# 1      MX  1675655452
# 2      GH  1675655452
# 3      PG  1675655453
# 4      IR  1675655453

# %%
# Export the City_Data into a csv
city_data_df.to_csv("./output_data/cities.csv")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    Unnamed: 0       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           0    bubaque  11.2833  -15.8333     24.43        54         100
# 1           1    arcelia  18.2833 -100.2667     24.14        37           0
# 2           2     wenchi   7.7392   -2.1046     23.51        77          84
# 3           3    samarai -10.6167  150.6667     27.40        83          99
# 4           4  iranshahr  27.2025   60.6848     12.19        71           0
#
#    Wind Speed Country        Date
# 0        6.87      GW  1675655109
# 1        1.46      MX  1675655452
# 2        1.81      GH  1675655452
# 3        5.80      PG  1675655453
# 4        2.06      IR  1675655453

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"],city_data_df["Max Temp"]) 

# Incorporate the other graph properties
plt.ylabel("Max Temperature")
plt.title("City Max Latitude VS Temperature")
plt.xlabel("Latitude")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"],city_data_df["Humidity"]) 

# Incorporate the other graph properties
plt.ylabel("Humidity (%)")
plt.title("City Latitude VS Humidity")
plt.xlabel("Latitude")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"],city_data_df["Cloudiness"]) 


# Incorporate the other graph properties
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude VS Cloudiness")
plt.xlabel("Latitude")


# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"],city_data_df["Wind Speed"]) 

# Incorporate the other graph properties
plt.ylabel("Wind Speed (m/s)")
plt.title("City Latitude VS Wind Speed")
plt.xlabel("Latitude")


# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE
def linear_function(x,y):
    z = np.polyfit(x, y, 1)
    p = np.poly1d(z)
    plt.scatter(x, y)
    #add trendline to plot
    plt.plot(x, p(x),color="red")
    plt.text(x.median(),y.median(),p, fontsize = 15,color="red")
    result = linregress(x, y)
    print(f"R-squared: {result.rvalue**2:.6f}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE
northern_hemi_df=city_data_df[city_data_df["Lat"]>=0]
# Display sample data
northern_hemi_df.head()
# Out:
#    Unnamed: 0       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           0    bubaque  11.2833  -15.8333     24.43        54         100
# 1           1    arcelia  18.2833 -100.2667     24.14        37           0
# 2           2     wenchi   7.7392   -2.1046     23.51        77          84
# 4           4  iranshahr  27.2025   60.6848     12.19        71           0
# 6           6     tromso  69.6496   18.9570      3.01        75          75
#
#    Wind Speed Country        Date
# 0        6.87      GW  1675655109
# 1        1.46      MX  1675655452
# 2        1.81      GH  1675655452
# 4        2.06      IR  1675655453
# 6        7.20      NO  1675655454

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE
southern_hemi_df=city_data_df[city_data_df["Lat"]<0]
# Display sample data
southern_hemi_df.head()
# Out:
#     Unnamed: 0       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 3            3    samarai -10.6167  150.6667     27.40        83          99
# 5            5     kawalu  -7.3817  108.2082     29.37        53         100
# 8            8   chiredzi -21.0500   31.6667     19.29        75           0
# 13          13    ushuaia -54.8000  -68.3000      5.81        65           0
# 14          14  busselton -33.6500  115.3333     27.16        43           0
#
#     Wind Speed Country        Date
# 3         5.80      PG  1675655453
# 5         0.17      ID  1675655454
# 8         0.90      ZW  1675655455
# 13        2.06      AR  1675655457
# 14        5.50      AU  1675655458

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x=northern_hemi_df["Lat"]
y=northern_hemi_df["Max Temp"]
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
linear_function(x, y)
plt.ylabel("Max Temp")
plt.xlabel("Latitude")
# Out:
# R-squared: 0.744149
# Text(0.5, 0, 'Latitude')

# %%
# Linear regression on Southern Hemisphere
x=southern_hemi_df["Lat"]
y=southern_hemi_df["Max Temp"]
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
linear_function(x, y)
plt.ylabel("Max Temp")
plt.xlabel("Latitude")
# Out:
# R-squared: 0.171589
# Text(0.5, 0, 'Latitude')

# %% [markdown]
# **Discussion about the linear relationship:**
# Based on the Linear regression plot and the R-squared values the max- temp and latitued has a
# stronger linear relashion in the Nothern Hemisphere, 1 unit latitued increase can decrease max temperature by 0.8242
# units on average.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x=northern_hemi_df["Lat"]
y=northern_hemi_df["Humidity"]
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
linear_function(x, y)
plt.ylabel("Humidity")
plt.xlabel("Latitude")
# Out:
# R-squared: 0.160321
# Text(0.5, 0, 'Latitude')

# %%
# Southern Hemisphere
x=southern_hemi_df["Lat"]
y=southern_hemi_df["Humidity"]
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
linear_function(x, y)
plt.ylabel("Humidity")
plt.xlabel("Latitude")
# Out:
# R-squared: 0.121684
# Text(0.5, 0, 'Latitude')

# %% [markdown]
# **Discussion about the linear relationship:**
# Humidity vs. Latitude Linear Regression Plot for the Nothern Hemisphere and Southern Hemisphere show no significant
# relation.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x=northern_hemi_df["Lat"]
y=northern_hemi_df["Cloudiness"]
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
linear_function(x, y)
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
# Out:
# R-squared: 0.087503
# Text(0.5, 0, 'Latitude')

# %%
# Southern Hemisphere
x=southern_hemi_df["Lat"]
y=southern_hemi_df["Cloudiness"]
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
linear_function(x, y)
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
# Out:
# R-squared: 0.152432
# Text(0.5, 0, 'Latitude')

# %% [markdown]
# **Discussion about the linear relationship:**
# The Northern Hemisphere shows R-squared: 0.059028 and Southern Hemisphere show R-squared: 0.152557

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x=northern_hemi_df["Lat"]
y=northern_hemi_df["Wind Speed"]
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
linear_function(x, y)
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
# Out:
# R-squared: 0.006625
# Text(0.5, 0, 'Latitude')

# %%
# Southern Hemisphere
x=southern_hemi_df["Lat"]
y=southern_hemi_df["Wind Speed"]
z = np.polyfit(x, y, 1)
p = np.poly1d(z)
linear_function(x, y)
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
# Out:
# R-squared: 0.071428
# Text(0.5, 0, 'Latitude')

# %% [markdown]
# **Discussion about the linear relationship:**
#
# The Nothern Hemisphere shows R-squared: 0.001183 and Southern Hemisphere show R-squared: 0.188577
